# %% [markdown]
# This Jupyter Notebook is to plot the throughput vs number of instances and number of concurrency for Exatrkx as a service.
# Author: Haoran Zhao
# Date: October 2023

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import re
from pathlib import Path

import mplhep as hep
hep.style.use(hep.style.ATLAS)

from utils import read_perf_analyzer_output, plot_backend_compare
from utils import plot_backend, check_inputpath, check_outputpath

# %% [markdown]
# # 1 instance on 1 GPU

# %%
custom_backend_results_path = "results/A100-40GB/instance_1/result_1instance_async.csv"
pd_custom = read_perf_analyzer_output(custom_backend_results_path)
var_name = "Inferences/Second"
custom_backend_results = {
    "Concurrency": pd_custom["Concurrency"],
    var_name: pd_custom[var_name]
}

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(custom_backend_results["Concurrency"], custom_backend_results[var_name], label="Custom Backend", marker="s")

ax.set_xlim(0, 11)
ax.set_xlabel("Number of Concurrent Requests")
ax.set_ylabel("Throughput [evt/s]")
ax.set_title("One NVIDIA A100-SXM4-40GB on Perlmutter", fontsize=22)
ax.set_ylim(0, 6.0)
ax.legend()
fig.savefig("./plots/throughput_vs_concurrency_1inst_1gpu.pdf", bbox_inches="tight")
# fig.savefig("throughput_vs_concurrency_1inst_1gpu.png", dpi=600, bbox_inches="tight")

# %%
custom_backend_results_path = "results/A100-40GB-4GPU/instance_1/result_1instance_async.csv"
pd_custom = read_perf_analyzer_output(custom_backend_results_path)
var_name = "Inferences/Second"
custom_backend_results = {
    "Concurrency": pd_custom["Concurrency"],
    var_name: pd_custom[var_name]
}

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(custom_backend_results["Concurrency"], custom_backend_results[var_name], label="Custom Backend", marker="s")

ax.set_xlim(0, 11)
ax.set_xlabel("Number of Concurrent Requests")
ax.set_ylabel("Throughput [evt/s]")
ax.set_title("4 NVIDIA A100-SXM4-40GB on Perlmutter", fontsize=22)
ax.set_ylim(0, 6.0)
ax.legend()
fig.savefig("./plots/throughput_vs_concurrency_1inst_4gpu.pdf", bbox_inches="tight")
# fig.savefig("throughput_vs_concurrency_1inst_1gpu.png", dpi=600, bbox_inches="tight")

# %% [markdown]
# # multiple instances on 1 GPU

# %%
fig, ax = plt.subplots(figsize=(9, 6))

for i in range(1,8):
    if i == 1 or i == 2 or i == 4 or i == 7:
        custom_backend_results_path = f"./results/A100-40GB_16concur/instance_{i}/result_{i}instance_async.csv"
        pd_custom = read_perf_analyzer_output(custom_backend_results_path)
        var_name = "Inferences/Second"
        custom_backend_results = {
            "Concurrency": pd_custom["Concurrency"],
            var_name: pd_custom[var_name]
        }
    
        ax.plot(custom_backend_results["Concurrency"], custom_backend_results[var_name], label=f"{i} instances", marker="s")

ax.set_xlim(0, 17)
ax.set_xlabel("Number of Concurrent Requests",fontsize=26)
ax.set_ylabel("Throughput [evt/s]",fontsize=26)
ax.set_title("One NVIDIA A100-SXM4-40GB on Perlmutter", fontsize=26)
ax.set_ylim(1.5, 1.9)
ax.legend(fontsize=16)
ax.grid()
plt.savefig("./plots/A100-40GB_16concur_throughput.pdf")

# %%
fig, ax = plt.subplots(figsize=(9, 6))

for i in range(1,8):
    custom_backend_results_path = f"./results/A100-80GB_16concur/instance_{i}/result_{i}instance_async.csv"
    pd_custom = read_perf_analyzer_output(custom_backend_results_path)
    var_name = "Inferences/Second"
    custom_backend_results = {
        "Concurrency": pd_custom["Concurrency"],
        var_name: pd_custom[var_name]
    }

    ax.plot(custom_backend_results["Concurrency"], custom_backend_results[var_name], label=f"{i} instances", marker="s")

ax.set_xlim(0, 17)
ax.set_xlabel("Number of Concurrent Requests",fontsize=26)
ax.set_ylabel("Throughput [evt/s]",fontsize=26)
ax.set_title("One NVIDIA A100-SXM4-80GB on Perlmutter", fontsize=26)
ax.set_ylim(1.1, 1.8)
ax.legend(fontsize=16)
ax.grid()
plt.savefig("./plots/A100-80GB_16concur_throughput.pdf")

# %% [markdown]
# # Max Throughput vs instances

# %%
custom_backend_results_path = "./results/A100-40GB/"
custom_backend_results_path = check_inputpath(custom_backend_results_path)

pattern = r'instance_(\d+)'
sync_mode = "async"
n_instance_threshold = 7

def extract_number_GPUutilization(s):
    match = re.search(r'(\d+\.\d+)', s)
    if match:
        return float(match.group(1))
    return None

def exatract_perf_vs_instances(backend_results_path):
    backend_results = {
        "n_instances": [],
        "Throughput_mean": [],
        "Throughput_std": [], 
        "GPU Utilization": [],
    }
    for item in backend_results_path.iterdir():
        print(item)
    different_ins_results_path = sorted([item for item in backend_results_path.iterdir() if item.is_dir()])
    #print(different_ins_results_path)
    for instance_result_path in different_ins_results_path:
        #print(instance_result_path.stem)
        match = re.search(pattern, instance_result_path.stem)
        if match:
            n_instance = int(match.group(1)) 
            #print(n_instance)
        else:
            # raise ValueError("No instance number found in the path.") 
            print(f"No instance number found in the path: {instance_result_path}")
            continue

        backend_results["n_instances"].append(n_instance)
        csv_file_pattern = f"*_{sync_mode}.csv"
        csv_file = sorted(instance_result_path.glob(csv_file_pattern))[0]

        pd_csv = read_perf_analyzer_output(csv_file)

        pd_saturated = pd_csv.query(f"Concurrency >= {n_instance_threshold}")
        backend_results["Throughput_mean"].append(pd_saturated[var_name].mean())
        backend_results["Throughput_std"].append(pd_saturated[var_name].std())
        
        # gpu_util = pd_saturated['Avg GPU Utilization'].apply(extract_number_GPUutilization).mean()
        gpu_util = pd_saturated['Avg GPU Utilization'].mean()[-1]
        backend_results["GPU Utilization"].append(gpu_util)

    return backend_results

# %%
custom_backend_results = exatract_perf_vs_instances(custom_backend_results_path)
# Out:
# results/A100-40GB/instance_1
# results/A100-40GB/instance_2
# results/A100-40GB/instance_7
# results/A100-40GB/instance_4
# results/A100-40GB/instance_3
# results/A100-40GB/instance_5
# results/A100-40GB/instance_6

# %%
fig, ax = plt.subplots(figsize=(9, 6))
plt.tight_layout()
ax.set_xticks(custom_backend_results["n_instances"])
ax.errorbar(custom_backend_results["n_instances"], 
            custom_backend_results["Throughput_mean"], 
            yerr=custom_backend_results["Throughput_std"], 
            label="Custom Backend", color="black")

# twin object for two different y-axis on the sample plot
ax2_color = "red"
ax2=ax.twinx()
ax2.plot(custom_backend_results["n_instances"], 
         np.array(custom_backend_results["GPU Utilization"]) * 100, 
         label="GPU Utilization", color="red", marker="s")

ax2.tick_params(axis='y', colors=ax2_color)
ax2.spines['right'].set_color(ax2_color)

ax.set_xlabel("Number of Triton Model Instances",fontsize=26)
ax.set_ylabel("Throughput [evt/s]",fontsize=26)
ax.set_ylim(1.55, 1.85)
ax.set_title("One NVIDIA A100-SXM4-40GB on Perlmutter", fontsize=26)

ax2.set_ylim(0,105)
ax2.set_ylabel("GPU Utilization [%]", color=ax2_color,fontsize=26)

ax.set_xlim(0.8, 7.2)
fig.savefig("./plots/A100-40GB_GPUutil.pdf", bbox_inches='tight')
# fig.savefig("avg_throughput_vs_instances_1gpu.pdf", dpi=600, bbox_inches="tight")
# fig.savefig("avg_throughput_vs_instances_1gpu.png", dpi=600, bbox_inches="tight")

# %%
custom_backend_results_path = "./results/A100-80GB/"
custom_backend_results_path = check_inputpath(custom_backend_results_path)
custom_backend_results = exatract_perf_vs_instances(custom_backend_results_path)
# Out:
# results/A100-80GB/instance_1
# results/A100-80GB/instance_2
# results/A100-80GB/instance_7
# results/A100-80GB/instance_4
# results/A100-80GB/instance_3
# results/A100-80GB/instance_5
# results/A100-80GB/instance_6

# %%
fig, ax = plt.subplots(figsize=(9, 6))
plt.tight_layout()
ax.set_xticks(custom_backend_results["n_instances"])
ax.errorbar(custom_backend_results["n_instances"], 
            custom_backend_results["Throughput_mean"], 
            yerr=custom_backend_results["Throughput_std"], 
            label="Custom Backend", color="black")

# twin object for two different y-axis on the sample plot
ax2_color = "red"
ax2=ax.twinx()
ax2.plot(custom_backend_results["n_instances"], 
         np.array(custom_backend_results["GPU Utilization"]) * 100, 
         label="GPU Utilization", color="red", marker="s")

ax2.tick_params(axis='y', colors=ax2_color)
ax2.spines['right'].set_color(ax2_color)

ax.set_xlabel("Number of Triton Model Instances",fontsize=26)
ax.set_ylabel("Throughput [evt/s]",fontsize=26)
ax.set_ylim(1.55, 1.85)
ax.set_title("One NVIDIA A100-SXM4-80GB on Perlmutter", fontsize=26)

ax2.set_ylim(0,105)
ax2.set_ylabel("GPU Utilization [%]", color=ax2_color,fontsize=26)

ax.set_xlim(0.8, 7.2)
fig.savefig("./plots/A100-80GB_GPUutil.pdf", bbox_inches='tight')
# fig.savefig("avg_throughput_vs_instances_1gpu.pdf", dpi=600, bbox_inches="tight")
# fig.savefig("avg_throughput_vs_instances_1gpu.png", dpi=600, bbox_inches="tight")
